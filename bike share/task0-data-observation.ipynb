# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("default")
import seaborn as sns
sns.set()

# %%
bike_df = pd.read_csv("hour.csv")
bike_df.head(3)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %% [markdown]
# #### check missing values

# %%
bike_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# It's a good thing that there are no missing values

# %%
bike_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
bike_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# `cnt` is the target column and others are feature columns. From the dataset, `instant` and `dteday` columns can be ignored

# %% [markdown]
# ### Feature: `season`
#
# - 0: spring
# - 1: summer
# - 2: fall
# - 3: winter

# %%
plt.figure(figsize=(10, 2))
sns.countplot(y="season", data=bike_df)
print(bike_df.season.value_counts().sort_index())
# Out:
# 1    4242
# 2    4409
# 3    4496
# 4    4232
# Name: season, dtype: int64

# %% [markdown]
# ### Feature: `yr`

# %%
plt.figure(figsize=(10, 1))
sns.countplot(y="yr", data=bike_df)
print(bike_df.yr.value_counts().sort_index())
# 0: 2011, 1: 2012
# Out:
# 0    8645
# 1    8734
# Name: yr, dtype: int64

# %% [markdown]
# ### Feature: `mnth`

# %%
plt.figure(figsize=(10, 4))
sns.countplot(y="mnth", data=bike_df)
print(bike_df.mnth.value_counts().sort_index())
# Out:
# 1     1429
# 2     1341
# 3     1473
# 4     1437
# 5     1488
# 6     1440
# 7     1488
# 8     1475
# 9     1437
# 10    1451
# 11    1437
# 12    1483
# Name: mnth, dtype: int64

# %% [markdown]
# ### Feature: `hr`

# %%
plt.figure(figsize=(20, 8))
sns.countplot(y="hr", data=bike_df)
# print(bike_df.hr.value_counts().sort_index())

# %% [markdown]
# ### Feature: `holiday`

# %%
plt.figure(figsize=(10, 1))
sns.countplot(y="holiday", data=bike_df)
print(bike_df.holiday.value_counts().sort_index())
# Out:
# 0    16879
# 1      500
# Name: holiday, dtype: int64

# %% [markdown]
# ### Feature: `weekday`

# %%
plt.figure(figsize=(20, 4))
sns.countplot(y="weekday", data=bike_df)
print(bike_df.weekday.value_counts().sort_index())
# Out:
# 0    2502
# 1    2479
# 2    2453
# 3    2475
# 4    2471
# 5    2487
# 6    2512
# Name: weekday, dtype: int64

# %% [markdown]
# ### Feature: `workingday`
#
# - 1: neither weekend nor holiday
# - 0: either weekend or holiday

# %%
plt.figure(figsize=(10, 1))
sns.countplot(y="workingday", data=bike_df)
print(bike_df.workingday.value_counts().sort_index())
# Out:
# 0     5514
# 1    11865
# Name: workingday, dtype: int64

# %% [markdown]
# ### Feature: `weathersit`
#
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
plt.figure(figsize=(10, 2))
sns.countplot(y="weathersit", data=bike_df)
print(bike_df.weathersit.value_counts().sort_index())
# Out:
# 1    11413
# 2     4544
# 3     1419
# 4        3
# Name: weathersit, dtype: int64

# %% [markdown]
# ### Feature: `temp`

# %%
sns.distplot(bike_df["temp"]);

# %% [markdown]
# ### Feature: `atemp`

# %%
sns.distplot(bike_df["atemp"]);

# %% [markdown]
# ### Feature: `humidity`

# %%
sns.distplot(bike_df["hum"]);

# %% [markdown]
# ### Feature: `windspeed`

# %%
sns.distplot(bike_df["windspeed"]);

# %% [markdown]
# ### correlation

# %%
my_df = bike_df.drop(["instant", "dteday", "casual", "registered"], axis=1)
my_df.head(2)
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
#
#     atemp   hum  windspeed  cnt
# 0  0.2879  0.81        0.0   16
# 1  0.2727  0.80        0.0   40

# %%
my_df.corr()
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.010742  0.830386 -0.006117 -0.009585 -0.002335
# yr         -0.010742  1.000000 -0.010473 -0.003867  0.006692 -0.004485
# mnth        0.830386 -0.010473  1.000000 -0.005772  0.018430  0.010400
# hr         -0.006117 -0.003867 -0.005772  1.000000  0.000479 -0.003498
# holiday    -0.009585  0.006692  0.018430  0.000479  1.000000 -0.102088
# weekday    -0.002335 -0.004485  0.010400 -0.003498 -0.102088  1.000000
# workingday  0.013743 -0.002196 -0.003477  0.002285 -0.252471  0.035955
# weathersit -0.014524 -0.019157  0.005400 -0.020203 -0.017036  0.003311
# temp        0.312025  0.040913  0.201691  0.137603 -0.027340 -0.001795
# atemp       0.319380  0.039222  0.208096  0.133750 -0.030973 -0.008821
# hum         0.150625 -0.083546  0.164411 -0.276498 -0.010588 -0.037158
# windspeed  -0.149773 -0.008740 -0.135386  0.137252  0.003988  0.011502
# ...

# %%
abs(my_df.corr())["cnt"].sort_values(ascending=False)
# Out:
# cnt           1.000000
# temp          0.404772
# atemp         0.400929
# hr            0.394071
# hum           0.322911
# yr            0.250495
# season        0.178056
# weathersit    0.142426
# mnth          0.120638
# windspeed     0.093234
# holiday       0.030927
# workingday    0.030284
# weekday       0.026900
# Name: cnt, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.scatter(x=my_df["temp"], y=my_df["cnt"])
plt.xlabel("temperature")
plt.ylabel("# of bikes")
plt.title("Bike share dataset")
plt.show()
